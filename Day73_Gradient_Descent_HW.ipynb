# %% [markdown]
# <a href="https://colab.research.google.com/github/kassy75035/1st-PyCrawlerMarathon/blob/master/Day73_Gradient_Descent_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
cur_x = 3
lr = 0.1

'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''

iters = 0
previous_step_size = 1
iters_history = [iters]
x_history =[cur_x]

while previous_step_size > precision and iters < max_iters:
  prev_x = cur_x
  cur_x = cur_x - lr * df(prev_x)
  previous_step_size = abs(cur_x - prev_x)
  iters = iters + 1
  print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
  iters_history.append(iters)
  x_history.append(cur_x)
# Out:
# the learning rate is 0.1
# Iteration 1
# X value is 1.4
# the learning rate is 0.1
# Iteration 2
# X value is 0.11999999999999966
# the learning rate is 0.1
# Iteration 3
# X value is -0.9040000000000001
# the learning rate is 0.1
# Iteration 4
# X value is -1.7232000000000003
# the learning rate is 0.1
# Iteration 5
# X value is -2.3785600000000002
# the learning rate is 0.1
# Iteration 6
# X value is -2.902848
# the learning rate is 0.1
# Iteration 7
# X value is -3.3222784
# the learning rate is 0.1
# Iteration 8
# X value is -3.65782272
# the learning rate is 0.1
# Iteration 9
# X value is -3.926258176
# the learning rate is 0.1
# Iteration 10
# X value is -4.1410065408
# the learning rate is 0.1
# Iteration 11
# X value is -4.312805232640001
# the learning rate is 0.1
# Iteration 12
# X value is -4.450244186112
# the learning rate is 0.1
# Iteration 13
# X value is -4.5601953488896
# the learning rate is 0.1
# Iteration 14
# X value is -4.64815627911168
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
#適用於 Jupyter Notebook, 宣告直接在cell 內印出執行結果

plt.plot(iters_history, x_history, 'o-', ms=3, lw=1.5, color='black')
plt.xlabel(r'$iters$', fontsize=16)
plt.ylabel(r'$x$', fontsize=16)
plt.show()

# %%
cur_x = 3
lr = 0.0001

'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''

iters = 0
previous_step_size = 1
iters_history = [iters]
x_history =[cur_x]

while previous_step_size > precision and iters < max_iters:
  prev_x = cur_x
  cur_x = cur_x - lr * df(prev_x)
  previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
  iters = iters + 1
  print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
  iters_history.append(iters)
  x_history.append(cur_x)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Iteration 8334
# X value is -3.4894484644741293
# the learning rate is 0.0001
# Iteration 8335
# X value is -3.4897505747812345
# the learning rate is 0.0001
# Iteration 8336
# X value is -3.490052624666278
# the learning rate is 0.0001
# Iteration 8337
# X value is -3.490354614141345
# the learning rate is 0.0001
# Iteration 8338
# X value is -3.4906565432185164
# the learning rate is 0.0001
# Iteration 8339
# X value is -3.490958411909873
# the learning rate is 0.0001
# Iteration 8340
# X value is -3.491260220227491
# the learning rate is 0.0001
# Iteration 8341
# X value is -3.4915619681834453
# the learning rate is 0.0001
# Iteration 8342
# X value is -3.4918636557898086
# the learning rate is 0.0001
# Iteration 8343
# X value is -3.4921652830586507
# the learning rate is 0.0001
# Iteration 8344
# X value is -3.492466850002039
# the learning rate is 0.0001
# Iteration 8345
# X value is -3.4927683566320384
# the learning rate is 0.0001
# Iteration 8346
# ...

# %%
plt.plot(iters_history, x_history, 'o-', ms=3, lw=1.5, color='black')
plt.xlabel(r'$iters$', fontsize=16)
plt.ylabel(r'$x$', fontsize=16)
plt.show()
