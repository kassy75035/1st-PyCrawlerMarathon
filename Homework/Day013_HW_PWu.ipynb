# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)
article_href = []
soup = BeautifulSoup(r.text, "html5lib")
for d in soup.find_all(class_="title"):
#     print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
#         print('https://www.ptt.cc'+d.find('a')['href'])
        results = r.select('span.article-meta-value')
        if results:
            print('作者:', results[0].text)
            print('標題:', results[2].text)
            print('時間:', results[3].text)
    
    except:
        continue
# Out:
# 作者: toto3527 (toto)
# 標題: [花邊] snoop doggy IG
# 時間: Thu Jan 30 13:38:45 2020
# 作者: blue999 (FLY)
# 標題: [新聞] 布萊恩性侵案檢察官不留情面 若受審他會
# 時間: Thu Jan 30 14:07:06 2020
# 作者: asdf1256 (guest)
# 標題: [新聞] 眾球星換背號向布萊恩致敬 華克則陷入
# 時間: Thu Jan 30 14:29:48 2020
# 作者: RedChoi ( )
# 標題: [情報] Judy Seto Twitter（Kobe御用復健師）
# 時間: Thu Jan 30 14:32:54 2020
# 作者: fukawa947 (交大薛之謙)
# 標題: [新聞] 不換背號嗎？八村壘繼續穿Kobe的8號　原
# 時間: Thu Jan 30 14:44:38 2020
# 作者: peacepork (peace)
# 標題: [花邊] 致敬柯比？正妹爆乳高衩泳裝衝賽場 高舉R
# 時間: Thu Jan 30 14:50:17 2020
# 作者: pneumo (超☆冒險蓋)
# 標題: [外絮] 聯盟準備公布2020-21薪資及奢侈稅預測
# 時間: Thu Jan 30 15:16:29 2020
# 作者: a221657947 (a221657947)
# 標題: [討論] 怎麼會有人特別去練logo shot
# 時間: Thu Jan 30 15:20:22 2020
# 作者: Vedan (味丹)
# 標題: [公告] 樂透取消及未來不再開啟樂透
# 時間: Mon Jun 24 15:08:02 2019
# 作者: qazwsx879345 (Rajon Rondo)
# 標題: [公告] 版主上任相關事項
# 時間: Fri Oct 25 10:44:03 2019
# 作者: Acetoxy (阿斯)
# 標題: [情報] SEASON Schedule 賽程 January 19–20
# 時間: Fri Jan  3 01:37:35 2020
# 作者: Vedan (味丹)
# 標題: [公告] 難過區
# 時間: Mon Jan 27 04:08:23 2020

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
# 爬 food 版
# https://ithelp.ithome.com.tw/articles/10204709
import requests
from bs4 import BeautifulSoup
article_href = []
r = requests.get("https://www.ptt.cc/bbs/Food/index.html")
soup = BeautifulSoup(r.text,"html.parser")
results = soup.select("div.title")
# print(results)

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
url="https://www.ptt.cc/bbs/Food/index.html"

def get_all_href(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    results = soup.select("div.title")
    for item in results:
        a_item = item.select_one("a")
        title = item.text
        if a_item:
            print(title, 'https://www.ptt.cc'+ a_item.get('href'))
        
for page in range(1,3):
    r = requests.get(url)
    soup = BeautifulSoup(r.text,"html.parser")
    btn = soup.select('div.btn-group > a')
    up_page_href = btn[3]['href']
    next_page_url = 'https://www.ptt.cc' + up_page_href
    url = next_page_url
    get_all_href(url = url)
# Out:
# [廣宣] 花蓮鳳林 沛甜點
#  https://www.ptt.cc/bbs/Food/M.1580308771.A.79B.html
#
# [食記] 佐藤咖哩 台灣台北 簡單純粹的美味咖哩
#  https://www.ptt.cc/bbs/Food/M.1580310244.A.023.html
#
# [食記] 桃園龍潭區。大江屋客家美食館
#  https://www.ptt.cc/bbs/Food/M.1580312056.A.EDA.html
#
# Fw: [食遊] 西屯/Arts and Crafts (酒吧)
#  https://www.ptt.cc/bbs/Food/M.1580313910.A.D26.html
#
# [食記] 台東市區 黑孩子黑咖啡
#  https://www.ptt.cc/bbs/Food/M.1580347169.A.656.html
#
# [食記] 宜蘭縣礁溪鄉 三妹爌肉飯
#  https://www.ptt.cc/bbs/Food/M.1580350795.A.F5C.html
#
# [食記] 新竹南寮 超人氣無名麵店 普通好吃
#  https://www.ptt.cc/bbs/Food/M.1580353862.A.285.html
#
# [食記] 苗栗 Sato和食 吃到飽或單點任君選
#  https://www.ptt.cc/bbs/Food/M.1580354419.A.A70.html
#
# [食記] 台北大直 揚屋大眾日式料理 平價不廉價
#  https://www.ptt.cc/bbs/Food/M.1580364106.A.D59.html
#
# [食記] 台北 中山 伊藤久右衛門‧茶房
#  https://www.ptt.cc/bbs/Food/M.1580365150.A.127.html
#
# [食記] 台北 信義 撈王
#  https://www.ptt.cc/bbs/Food/M.1580365255.A.DD0.html
#
# [食記] 桃園 桃園觀光夜市小吃
#  https://www.ptt.cc/bbs/Food/M.1580365375.A.E86.html
#
# [食記] 台北松山 雅閣 文華東方 米其林一星 再來試脆皮雞
#  https://www.ptt.cc/bbs/Food/M.1580370298.A.F36.html
#
# [食記] 台北中山意舍酒店 美國肋眼牛排
#  https://www.ptt.cc/bbs/Food/M.1580370475.A.D1D.html
#
# [食記] 高雄 鴨肉和 人氣爆棚鴨肉店
#  https://www.ptt.cc/bbs/Food/M.1580372610.A.1F0.html
#
# [食記] 宜蘭縣宜蘭市 復興路炸醬麵
#  https://www.ptt.cc/bbs/Food/M.1580374167.A.066.html
#
# [請益] 台北好吃gelato
#  https://www.ptt.cc/bbs/Food/M.1580379646.A.A32.html
#
# [食記] 新北永和 小義食義大利麵 墨西哥烤餅好吃
#  https://www.ptt.cc/bbs/Food/M.1580388052.A.245.html
#
# [食記] 台北多明尼加 El punto南美風情臻品料理
#  https://www.ptt.cc/bbs/Food/M.1580389040.A.20D.html
#
# [食記] 台南 老東門 虱目魚餐飲店 蝦仁飯20元
#  https://www.ptt.cc/bbs/Food/M.1580389424.A.D5F.html
